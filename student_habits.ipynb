# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghena-A/student-performance-linear-regression/blob/main/student_habits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/student_habits_performance2.csv')

# %%
data.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
data = data.drop('student_id', axis=1)

# %%
data.sample(5)
# Out:
#      age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 935   17    Male                  3.4                 4.0            0.7
# 415   17    Male                  3.4                 1.2            2.1
# 482   21    Male                  3.4                 1.5            0.7
# 279   18  Female                  4.6                 0.6            2.1
# 67    17    Male                  3.3                 1.8            3.2
#
#     part_time_job  attendance_percentage  sleep_hours diet_quality  \
# 935           Yes                   87.1          7.3         Poor
# 415           Yes                   88.8          5.3         Fair
# 482            No                   79.3          7.1         Fair
# 279            No                   90.0          4.5         Poor
# 67             No                   81.7          5.8         Poor
#
#      exercise_frequency parental_education_level internet_quality  \
# ...

# %%
data.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxenplot(x=data['social_media_hours'])
plt.show()

# %%
# تحديد الحد الأعلى 6 ساعات
data["social_media_hours"] = data["social_media_hours"].clip(lower=0, upper=6)

# %%
sns.boxenplot(x=data['social_media_hours'])
plt.show()

# %%
data["social_media_hours"].describe()
# Out:
# count    1000.000000
# mean        2.504000
# std         1.167299
# min         0.000000
# 25%         1.700000
# 50%         2.500000
# 75%         3.300000
# max         6.000000
# Name: social_media_hours, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            1000 non-null   int64
#  1   gender                         1000 non-null   object
#  2   study_hours_per_day            1000 non-null   float64
#  3   social_media_hours             1000 non-null   float64
#  4   netflix_hours                  1000 non-null   float64
#  5   part_time_job                  1000 non-null   object
#  6   attendance_percentage          1000 non-null   float64
#  7   sleep_hours                    1000 non-null   float64
#  8   diet_quality                   1000 non-null   object
#  9   exercise_frequency             1000 non-null   int64
#  10  parental_education_level       909 non-null    object
#  11  internet_quality               1000 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['age', 'gender', 'study_hours_per_day', 'social_media_hours',
#        'netflix_hours', 'part_time_job', 'attendance_percentage',
#        'sleep_hours', 'diet_quality', 'exercise_frequency',
#        'parental_education_level', 'internet_quality', 'mental_health_rating',
#        'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 15)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(data.select_dtypes(include='number').corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
data.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23  Female                  0.0                 1.2            1.1
# 1   20  Female                  6.9                 2.8            2.3
# 2   21    Male                  1.4                 3.1            1.3
# 3   23  Female                  1.0                 3.9            1.0
# 4   19  Female                  5.0                 4.4            0.5
#
#   part_time_job  attendance_percentage  sleep_hours diet_quality  \
# 0            No                   85.0          8.0         Fair
# 1            No                   97.3          4.6         Good
# 2            No                   94.8          8.0         Poor
# 3            No                   71.0          9.2         Poor
# 4            No                   90.9          4.9         Fair
#
#    exercise_frequency parental_education_level internet_quality  \
# 0                   6                   Master          Average
# ...

# %%
sns.scatterplot(x="mental_health_rating", y="exam_score", data=data)
plt.show()

# %%
sns.scatterplot(x="parental_education_level",y="exam_score",data=data)
plt.show()

# %%
data=data.drop('parental_education_level',axis=1)

# %%
data.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23  Female                  0.0                 1.2            1.1
# 1   20  Female                  6.9                 2.8            2.3
# 2   21    Male                  1.4                 3.1            1.3
# 3   23  Female                  1.0                 3.9            1.0
# 4   19  Female                  5.0                 4.4            0.5
#
#   part_time_job  attendance_percentage  sleep_hours diet_quality  \
# 0            No                   85.0          8.0         Fair
# 1            No                   97.3          4.6         Good
# 2            No                   94.8          8.0         Poor
# 3            No                   71.0          9.2         Poor
# 4            No                   90.9          4.9         Fair
#
#    exercise_frequency internet_quality  mental_health_rating  \
# 0                   6          Average                     8
# ...

# %%
data['diet_quality'].unique()
# Out:
# array(['Fair', 'Good', 'Poor'], dtype=object)

# %%
data['exercise_frequency'].unique()
# Out:
# array([6, 1, 4, 3, 2, 0, 5])

# %%
data['sleep_hours'].unique()
# Out:
# array([ 8. ,  4.6,  9.2,  4.9,  7.4,  6.5,  7.1,  7.5,  5.8,  7.9,  4.5,
#         4.7,  6.7,  5.6,  6.4,  7.2,  6. ,  9. ,  5.5,  4.8,  8.1,  6.9,
#         7.7,  7.3,  3.9,  7. ,  5.7,  8.5,  6.8,  5.3,  8.4,  8.9,  5. ,
#         5.1,  5.2,  5.4,  6.2,  6.1,  7.8,  9.1,  6.3,  9.5,  6.6,  4.1,
#         7.6,  8.3,  8.2,  9.7,  9.4,  5.9,  9.3,  8.7,  8.8,  4.4,  3.2,
#         3.5,  4.2,  9.8,  4. ,  8.6,  3.7,  4.3,  3.4,  3.8,  3.6,  3.3,
#        10. ,  9.6])

# %%
def lifestyle_score(row):
    # diet
    if row['diet_quality'] == 'Poor':
        diet = 0
    elif row['diet_quality'] == 'Fair':
        diet = 1
    else:  # Good
        diet = 2

    # exercise
    if row['exercise_frequency'] <= 1:
        exercise = 0
    elif 2 <= row['exercise_frequency'] <= 4:
        exercise = 1
    else:  # 5-6
        exercise = 2

    # sleep
    if row['sleep_hours'] < 6:
        sleep = 0
    elif 6 <= row['sleep_hours'] <= 8:
        sleep = 1
    else:
        sleep = 2


    total = diet + exercise + sleep

    if total <= 2:
        return 'Poor'
    elif 3 <= total <= 4:
        return 'Fair'
    else:
        return 'Good'

data['life_style'] = data.apply(lifestyle_score, axis=1)

# %%
print(data["life_style"].value_counts())
# Out:
# life_style
# Fair    546
# Poor    348
# Good    106
# Name: count, dtype: int64

# %%
data['life_style']
# Out:
# 0      Fair
# 1      Fair
# 2      Poor
# 3      Fair
# 4      Poor
#        ...
# 995    Fair
# 996    Poor
# 997    Good
# 998    Poor
# 999    Fair
# Name: life_style, Length: 1000, dtype: object

# %%
data.drop(['diet_quality', 'exercise_frequency', 'sleep_hours'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23  Female                  0.0                 1.2            1.1
# 1   20  Female                  6.9                 2.8            2.3
# 2   21    Male                  1.4                 3.1            1.3
# 3   23  Female                  1.0                 3.9            1.0
# 4   19  Female                  5.0                 4.4            0.5
#
#   part_time_job  attendance_percentage internet_quality  mental_health_rating  \
# 0            No                   85.0          Average                     8
# 1            No                   97.3          Average                     8
# 2            No                   94.8             Poor                     1
# 3            No                   71.0             Good                     1
# 4            No                   90.9             Good                     1
#
#   extracurricular_participation  exam_score life_style
# ...

# %%
sns.boxplot(x='life_style', y='mental_health_rating', data=data)
plt.show()

# %%
sns.boxplot(x='life_style', y='exam_score', data=data)
plt.show()

# %%
data.sample(10)
# Out:
#      age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 200   23  Female                  3.5                 1.3            0.5
# 853   19  Female                  2.1                 0.8            2.0
# 600   21    Male                  6.0                 3.3            2.2
# 566   18    Male                  2.7                 3.7            2.3
# 539   18    Male                  3.8                 4.1            1.6
# 679   18  Female                  3.2                 2.3            1.5
# 319   22    Male                  2.8                 3.3            3.3
# 803   17  Female                  4.5                 1.2            2.6
# 392   24  Female                  2.2                 4.7            2.2
# 434   20    Male                  0.0                 3.5            3.2
#
#     part_time_job  attendance_percentage internet_quality  \
# 200            No                   89.8             Good
# ...

# %%
data['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
data['gender'].replace({'Male': 0, 'Female': 1 ,'Other':2}, inplace=True)
# Out:
# /tmp/ipython-input-2022208886.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['gender'].replace({'Male': 0, 'Female': 1 ,'Other':2}, inplace=True)
# /tmp/ipython-input-2022208886.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['part_time_job'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['part_time_job'].replace({'No': 0, 'Yes': 1}, inplace=True)
# Out:
# /tmp/ipython-input-2446051418.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['part_time_job'].replace({'No': 0, 'Yes': 1}, inplace=True)
# /tmp/ipython-input-2446051418.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['internet_quality'].unique()
# Out:
# array(['Average', 'Poor', 'Good'], dtype=object)

# %%
data['internet_quality'].replace({'Poor': 0, 'Average': 1, 'Good': 2}, inplace=True)
# Out:
# /tmp/ipython-input-1850478051.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['internet_quality'].replace({'Poor': 0, 'Average': 1, 'Good': 2}, inplace=True)
# /tmp/ipython-input-1850478051.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['extracurricular_participation'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['extracurricular_participation'].replace({'No': 0, 'Yes': 1}, inplace=True)
# Out:
# /tmp/ipython-input-4037333282.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['extracurricular_participation'].replace({'No': 0, 'Yes': 1}, inplace=True)
# /tmp/ipython-input-4037333282.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['life_style'].unique()
# Out:
# array(['Fair', 'Poor', 'Good'], dtype=object)

# %%
data['life_style'].replace({'Poor': 0, 'Fair': 1, 'Good': 2}, inplace=True)
# Out:
# /tmp/ipython-input-4236549685.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['life_style'].replace({'Poor': 0, 'Fair': 1, 'Good': 2}, inplace=True)
# /tmp/ipython-input-4236549685.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23       1                  0.0                 1.2            1.1
# 1   20       1                  6.9                 2.8            2.3
# 2   21       0                  1.4                 3.1            1.3
# 3   23       1                  1.0                 3.9            1.0
# 4   19       1                  5.0                 4.4            0.5
#
#    part_time_job  attendance_percentage  internet_quality  \
# 0              0                   85.0                 1
# 1              0                   97.3                 1
# 2              0                   94.8                 0
# 3              0                   71.0                 2
# 4              0                   90.9                 2
#
#    mental_health_rating  extracurricular_participation  exam_score  life_style
# 0                     8                              1        56.2           1
# ...

# %%
x=data.drop('exam_score',axis=1)
y=data['exam_score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 42.784656574499216
# R^2 Score: 0.8478888000340878

# %%
coefficients = pd.DataFrame({
    'Feature': x.columns,
    'Coefficient': model.coef_
})
print(coefficients)
# Out:
#                           Feature  Coefficient
# 0                             age    -0.052902
# 1                          gender    -0.156970
# 2             study_hours_per_day     9.516676
# 3              social_media_hours    -2.916461
# 4                   netflix_hours    -2.396797
# 5                   part_time_job    -0.127238
# 6           attendance_percentage     0.148373
# 7                internet_quality    -0.051387
# 8            mental_health_rating     1.923111
# 9   extracurricular_participation     0.244633
# 10                     life_style     3.785941

# %% [markdown]
# **Model Performance**

# %%
coefficients = pd.DataFrame({
    'Feature': x.columns,
    'Coefficient': model.coef_
}).sort_values(by='Coefficient', ascending=False)

plt.figure(figsize=(8,6))
plt.barh(coefficients['Feature'], coefficients['Coefficient'])
plt.xlabel("Coefficient Value")
plt.title("Feature Impact on Target")
plt.show()

# %%
plt.scatter(y_test, y_pred, alpha=0.7)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.show()

# %%
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results.head(10))
# Out:
#      Actual  Predicted
# 377    67.9  63.268899
# 61     75.0  72.834088
# 378    63.6  61.699014
# 996    65.9  65.061735
# 845    78.1  72.533718
# 530    80.9  86.608705
# 117    80.8  84.195361
# 946    55.0  50.991572
# 744    52.6  59.509981
# 64     68.6  65.780616
